# %% [markdown]
# # CSV to JSON
#
# After finishing to collect data, all files should be converted into JSON format.

# %%
# Outputs
OUTPUT_PATHNAME = './world-campus-220212-1.json'

# %%
import numpy as np
import pandas as pd
pd.options.display.max_columns = None

import json
import itertools

# Inputs
PRGM_PATHNAME = '../univ-program/program.csv'

UNIV_PATHNAME = '../qs-rankings/univ-with-qs.csv'  # With QS Rankings

UNIV_CITY_PATHNAME = '../weather/univ-city.csv'    # University - City (for weather)
WTHR_PATHNAME = '../weather/city-weather.json'

CTRY_PATHNAME = '../country/country-stat.csv'

CTRY_CODE_PATHNAME = '../covid19/country-code.csv' # Country - Code (for COVID-19 Graph)
COVD_PATHNAME = '../covid19/covid19-graph.csv'

# %%
ctry_mapper = {
    'UK': 'United Kingdom',
    'United States of America': 'United States'
}

def update_country(df):
    # Get columns related to country
    cols = [x for x in df.columns if x.endswith('country')]
    
    for col_name, kv in itertools.product(cols, ctry_mapper.items()):
        # Convert country
        df.loc[df[col_name] == kv[0], col_name] = kv[1]

# Initialize output
output_info = dict()

# %% [markdown]
# ## University (+ City ID + Country Code)

# %%
df_univ = pd.read_csv(UNIV_PATHNAME)
print('univ', df_univ.columns)

# Merge University and City ID
df_city = pd.read_csv(UNIV_CITY_PATHNAME)
df_city.rename(columns={
    'country': 'univ-country',
    'city': 'univ-city',
    'CityId': 'city-id'
}, inplace=True)
print('city', df_city.columns)

# Merge University and Country code
df_code = pd.read_csv(CTRY_CODE_PATHNAME)
df_code.rename(columns={'code': 'country-code'}, inplace=True)
print('code', df_code.columns)
# Out:
# univ Index(['sequence', 'name', 'region', 'country', 'city', 'official-link',
#        'established', 'student-number', 'faculty-number', 'campus-size',
#        'map-iframe', 'loc', 'tot-rank', 'tot-score',
#        'tot-international-students-ratio', 'tot-international-faculty-ratio',
#        'tot-faculty-student ratio', 'tot-citations-per-faculty',
#        'tot-academic-reputation', 'tot-employer-reputation', 'cse-rank',
#        'cse-overall-score', 'cse-h-index-citations', 'cse-citations-per paper',
#        'cse-academic-reputation', 'cse-employer-reputation', 'hum-rank',
#        'hum-overall-score', 'hum-h-index-citations', 'hum-citations-per-paper',
#        'hum-academic-reputation', 'hum-employer-reputation'],
#       dtype='object')
# city Index(['sequence', 'name', 'region', 'univ-country', 'univ-city', 'city-id'], dtype='object')
# code Index(['univ-country', 'country-code'], dtype='object')

# %%
# Merge
df_univ = pd.merge(left=df_univ, right=df_city[['sequence', 'univ-city', 'city-id']],
                   left_on='sequence', right_on='sequence')
df_univ.rename(columns={'univ-city': 'city'}, inplace=True)

# %%
# Merge
df_univ = pd.merge(left=df_univ, right=df_code, how='left',
                   left_on='country', right_on='univ-country')

# %%
df_univ.drop(columns=['sequence', 'city', 'univ-country'], inplace=True)
df_univ.tail()
# Out:
#                                    name       region    country official-link  \
# 83                    Kuwait University  Middle East     Kuwait           NaN
# 84  Queensland University of Technology      Oceania  Australia           NaN
# 85        University of South Australia      Oceania  Australia           NaN
# 86        University of New South Wales      Oceania  Australia           NaN
# 87                    Deakin University      Oceania  Australia           NaN
#
#     established  student-number  faculty-number  campus-size map-iframe  \
# 83          NaN             NaN             NaN          NaN        NaN
# 84          NaN             NaN             NaN          NaN        NaN
# 85          NaN             NaN             NaN          NaN        NaN
# 86          NaN             NaN             NaN          NaN        NaN
# 87          NaN             NaN             NaN          NaN        NaN
#
#                    loc   tot-rank tot-score  tot-international-students-ratio  \
# 83  Kuwait City,Kuwait  1001-1200         -                              28.4
# 84  Brisbane,Australia        213      42.1                              43.3
# 85    Magill,Australia       =326      32.8                              70.4
# 86    Sydney,Australia         43      77.7                              99.8
# 87   Geelong,Australia        283      36.1                              72.4
#
#     tot-international-faculty-ratio  tot-faculty-student ratio  \
# 83                             19.3                        5.1
# 84                             98.3                        8.7
# 85                            100.0                       20.6
# 86                            100.0                       15.2
# 87                             98.7                        4.4
#
#     tot-citations-per-faculty  tot-academic-reputation  \
# 83                        3.4                     11.8
# 84                       59.0                     42.0
# 85                       45.6                     23.1
# 86                       93.5                     90.4
# 87                       57.1                     28.1
#
#     tot-employer-reputation cse-rank  cse-overall-score  \
# 83                      6.9  501-550                NaN
# 84                     44.8     =132               66.4
# 85                     16.7  251-300                NaN
# 86                     94.4      =59               73.4
# 87                     38.0  201-250                NaN
#
#     cse-h-index-citations  cse-citations-per paper  cse-academic-reputation  \
# 83                    NaN                      NaN                      NaN
# 84                   80.8                     85.6                     57.1
# 85                    NaN                      NaN                      NaN
# 86                   87.0                     83.4                     61.9
# 87                    NaN                     85.4                      NaN
#
#     cse-employer-reputation hum-rank  hum-overall-score  \
# 83                      NaN  501-550                NaN
# 84                     62.1     =132               66.4
# 85                      NaN  251-300                NaN
# 86                     76.8      =59               73.4
# 87                      NaN  201-250                NaN
#
#     hum-h-index-citations  hum-citations-per-paper  hum-academic-reputation  \
# 83                    NaN                      NaN                      NaN
# 84                   80.8                     85.6                     57.1
# 85                    NaN                      NaN                      NaN
# 86                   87.0                     83.4                     61.9
# 87                    NaN                     85.4                      NaN
#
#     hum-employer-reputation  city-id country-code
# 83                      NaN   1498.0          KWT
# 84                     62.1    320.0          AUS
# 85                      NaN   1676.0          AUS
# 86                     76.8    300.0          AUS
# 87                      NaN    402.0          AUS

# %%
# Set index
df_univ.drop_duplicates(ignore_index=True, inplace=True)
df_univ.set_index('name', inplace=True)
df_univ.head()
# Out:
#                                                region      country  \
# name
# GE3(Global Engineering Education Exchange)     Others          NaN
# ISEP(International Student Exchange Programs)  Others          NaN
# University of Twente                           Europe  Netherlands
# Amsterdam University of Applied Sciences       Europe  Netherlands
# Fontys University of Applied Sciences          Europe  Netherlands
#
#                                                                    official-link  \
# name
# GE3(Global Engineering Education Exchange)     https://globale3.studioabroad.com
# ISEP(International Student Exchange Programs)                                NaN
# University of Twente                                      http://www.utwente.nl/
# Amsterdam University of Applied Sciences                                     NaN
# Fontys University of Applied Sciences                                        NaN
#
#                                                established  student-number  \
# name
# GE3(Global Engineering Education Exchange)             NaN             NaN
# ISEP(International Student Exchange Programs)          NaN             NaN
# University of Twente                                1961.0         12544.0
# Amsterdam University of Applied Sciences               NaN             NaN
# Fontys University of Applied Sciences                  NaN             NaN
#
#                                                faculty-number  campus-size  \
# name
# GE3(Global Engineering Education Exchange)                NaN          NaN
# ISEP(International Student Exchange Programs)             NaN          NaN
# University of Twente                                   3150.0        146.0
# Amsterdam University of Applied Sciences                  NaN          NaN
# Fontys University of Applied Sciences                     NaN          NaN
#
#                                                                                       map-iframe  \
# name
# GE3(Global Engineering Education Exchange)                                                   NaN
# ISEP(International Student Exchange Programs)                                                NaN
# University of Twente                           https://www.google.com/maps/embed?pb=!1m18!1m1...
# Amsterdam University of Applied Sciences                                                     NaN
# Fontys University of Applied Sciences                                                        NaN
#
#                                                                 loc tot-rank  \
# name
# GE3(Global Engineering Education Exchange)                      NaN      NaN
# ISEP(International Student Exchange Programs)                   NaN      NaN
# University of Twente                           Enschede,Netherlands     =189
# Amsterdam University of Applied Sciences                        NaN      NaN
# Fontys University of Applied Sciences                           NaN      NaN
#
#                                               tot-score  \
# name
# GE3(Global Engineering Education Exchange)          NaN
# ISEP(International Student Exchange Programs)       NaN
# University of Twente                               45.5
# Amsterdam University of Applied Sciences            NaN
# Fontys University of Applied Sciences               NaN
#
#                                                tot-international-students-ratio  \
# name
# GE3(Global Engineering Education Exchange)                                  NaN
# ISEP(International Student Exchange Programs)                               NaN
# University of Twente                                                       89.1
# Amsterdam University of Applied Sciences                                    NaN
# Fontys University of Applied Sciences                                       NaN
#
#                                                tot-international-faculty-ratio  \
# name
# GE3(Global Engineering Education Exchange)                                 NaN
# ISEP(International Student Exchange Programs)                              NaN
# University of Twente                                                      98.8
# Amsterdam University of Applied Sciences                                   NaN
# Fontys University of Applied Sciences                                      NaN
#
#                                                tot-faculty-student ratio  \
# name
# GE3(Global Engineering Education Exchange)                           NaN
# ISEP(International Student Exchange Programs)                        NaN
# University of Twente                                                37.1
# Amsterdam University of Applied Sciences                             NaN
# Fontys University of Applied Sciences                                NaN
#
#                                                tot-citations-per-faculty  \
# name
# GE3(Global Engineering Education Exchange)                           NaN
# ISEP(International Student Exchange Programs)                        NaN
# University of Twente                                                79.3
# Amsterdam University of Applied Sciences                             NaN
# Fontys University of Applied Sciences                                NaN
#
#                                                tot-academic-reputation  \
# name
# GE3(Global Engineering Education Exchange)                         NaN
# ISEP(International Student Exchange Programs)                      NaN
# University of Twente                                              21.0
# Amsterdam University of Applied Sciences                           NaN
# Fontys University of Applied Sciences                              NaN
#
#                                                tot-employer-reputation  \
# name
# GE3(Global Engineering Education Exchange)                         NaN
# ISEP(International Student Exchange Programs)                      NaN
# University of Twente                                              42.3
# Amsterdam University of Applied Sciences                           NaN
# Fontys University of Applied Sciences                              NaN
#
#                                               cse-rank  cse-overall-score  \
# name
# GE3(Global Engineering Education Exchange)         NaN                NaN
# ISEP(International Student Exchange Programs)      NaN                NaN
# University of Twente                           151-200                NaN
# Amsterdam University of Applied Sciences           NaN                NaN
# Fontys University of Applied Sciences              NaN                NaN
#
#                                                cse-h-index-citations  \
# name
# GE3(Global Engineering Education Exchange)                       NaN
# ISEP(International Student Exchange Programs)                    NaN
# University of Twente                                             NaN
# Amsterdam University of Applied Sciences                         NaN
# Fontys University of Applied Sciences                            NaN
#
#                                                cse-citations-per paper  \
# name
# GE3(Global Engineering Education Exchange)                         NaN
# ISEP(International Student Exchange Programs)                      NaN
# University of Twente                                               NaN
# Amsterdam University of Applied Sciences                           NaN
# Fontys University of Applied Sciences                              NaN
#
#                                                cse-academic-reputation  \
# name
# GE3(Global Engineering Education Exchange)                         NaN
# ISEP(International Student Exchange Programs)                      NaN
# University of Twente                                               NaN
# Amsterdam University of Applied Sciences                           NaN
# Fontys University of Applied Sciences                              NaN
#
#                                                cse-employer-reputation  \
# name
# GE3(Global Engineering Education Exchange)                         NaN
# ISEP(International Student Exchange Programs)                      NaN
# University of Twente                                               NaN
# Amsterdam University of Applied Sciences                           NaN
# Fontys University of Applied Sciences                              NaN
#
#                                               hum-rank  hum-overall-score  \
# name
# GE3(Global Engineering Education Exchange)         NaN                NaN
# ISEP(International Student Exchange Programs)      NaN                NaN
# University of Twente                           151-200                NaN
# Amsterdam University of Applied Sciences           NaN                NaN
# Fontys University of Applied Sciences              NaN                NaN
#
#                                                hum-h-index-citations  \
# name
# GE3(Global Engineering Education Exchange)                       NaN
# ISEP(International Student Exchange Programs)                    NaN
# University of Twente                                             NaN
# Amsterdam University of Applied Sciences                         NaN
# Fontys University of Applied Sciences                            NaN
#
#                                                hum-citations-per-paper  \
# name
# GE3(Global Engineering Education Exchange)                         NaN
# ISEP(International Student Exchange Programs)                      NaN
# University of Twente                                               NaN
# Amsterdam University of Applied Sciences                           NaN
# Fontys University of Applied Sciences                              NaN
#
#                                                hum-academic-reputation  \
# name
# GE3(Global Engineering Education Exchange)                         NaN
# ISEP(International Student Exchange Programs)                      NaN
# University of Twente                                               NaN
# Amsterdam University of Applied Sciences                           NaN
# Fontys University of Applied Sciences                              NaN
#
#                                                hum-employer-reputation  \
# name
# GE3(Global Engineering Education Exchange)                         NaN
# ISEP(International Student Exchange Programs)                      NaN
# University of Twente                                               NaN
# Amsterdam University of Applied Sciences                           NaN
# Fontys University of Applied Sciences                              NaN
#
#                                                city-id country-code
# name
# GE3(Global Engineering Education Exchange)         NaN          NaN
# ISEP(International Student Exchange Programs)      NaN          NaN
# University of Twente                             145.0          NLD
# Amsterdam University of Applied Sciences           NaN          NLD
# Fontys University of Applied Sciences              NaN          NLD

# %%
update_country(df_univ)
output_info['university'] = json.loads(df_univ.to_json(orient='index'))

# %% [markdown]
# ## Program

# %%
df_prgm = pd.read_csv(PRGM_PATHNAME)
update_country(df_prgm)
output_info['program'] = json.loads(df_prgm.to_json(orient='records'))

# %% [markdown]
# ## Weather

# %%
df_wthr = pd.read_json(WTHR_PATHNAME)
df_wthr.set_index('cityId', drop=True, inplace=True)
df_wthr.head()
# Out:
#        lang    cityName  cityLatitude  cityLongitude  isCapital stationName  \
# cityId
# 145      en     Twenthe     52.270000       6.870000      False    Enschede
# 312      en      Zurich     47.380000       8.570000      False      Zurich
# 192      en  Luxembourg     49.616667       6.216667       True  Luxembourg
# 607      en      Kaunas     54.883960      23.835880      False      Kaunas
# 204      en     Vilnius     54.636389      25.290833       True     Vilnius
#
#              tourismURL                              tourismBoardName  isDep  \
# cityId
# 145     www.holland.com  Netherlands Board of Tourism and Conventions  False
# 312                                                                    False
# 192                                                                    False
# 607      www.tourism.lt        Lithuanian State Department of Tourism  False
# 204      www.tourism.lt        Lithuanian State Department of Tourism  False
#
#         timeZone isDST                                             member  \
# cityId
# 145          100     N  {'memId': 37, 'memName': 'Netherlands', 'short...
# 312          100     N  {'memId': 87, 'memName': 'Switzerland', 'short...
# 192          100     N  {'memId': 98, 'memName': 'Luxembourg', 'shortM...
# 607          200     N  {'memId': 105, 'memName': 'Lithuania', 'shortM...
# 204          200     N  {'memId': 105, 'memName': 'Lithuania', 'shortM...
#
#                                                  forecast  \
# cityId
# 145     {'issueDate': '2022-02-09 09:30:00', 'timeZone...
# 312     {'issueDate': '2022-02-08 12:00:00', 'timeZone...
# 192     {'issueDate': '2022-02-09 14:30:01', 'timeZone...
# 607     {'issueDate': '2022-02-09 12:37:00', 'timeZone...
# 204     {'issueDate': '2022-02-09 12:37:00', 'timeZone...
#
#                                                   climate
# cityId
# 145     {'raintype': 'PPT', 'raindef': '0.1', 'rainuni...
# 312     {'raintype': 'PPT', 'raindef': '1', 'rainunit'...
# 192     {'raintype': 'PPT', 'raindef': '0.1', 'rainuni...
# 607     {'raintype': 'PPT', 'raindef': '', 'rainunit':...
# 204     {'raintype': 'PPT', 'raindef': '', 'rainunit':...

# %%
output_info['weather'] = json.loads(df_wthr.to_json(orient='index'))

# %% [markdown]
# ## COVID-19

# %%
df_covd = pd.read_csv(COVD_PATHNAME)
df_covd.set_index('label', drop=True, inplace=True)
df_covd.head()
# Out:
#                  no                                              title  \
# label
# case              1  Biweekly confirmed COVID-19 cases per million ...
# death             2  Biweekly confirmed COVID-19 deaths per million...
# hospitalization   3             Weekly new ICU admissions for COVID-19
# vaccination       4        Share of people vaccinated against COVID-19
#
#                                                                url
# label
# case             https://ourworldindata.org/grapher/biweekly-co...
# death            https://ourworldindata.org/grapher/biweekly-co...
# hospitalization  https://ourworldindata.org/grapher/weekly-icu-...
# vaccination      https://ourworldindata.org/explorers/coronavir...

# %%
output_info['covid19'] = json.loads(df_covd.to_json(orient='index'))

# %%
with open(OUTPUT_PATHNAME, 'w') as f:
    json.dump(output_info, f)
