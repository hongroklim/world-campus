# %% [markdown]
# # Parse CSV into JSON
#
# [Offical recruit sheet file](2022-2-exchange-univ.csv) contains the information of **Exchange Program** and **University**. It will be labeled and divided into JSON file.
#
# The output JSON file looks like the followings;
#
# * program
# * university
# * city
# * country

# %%
import os
import pandas as pd

pd.options.display.max_columns = None
pd.options.display.float_format = '{:.2f}'.format

CSV_PATHNAME = "./2022-2-exchange-univ.csv"
DEST_PATHNAME = "./world-campus.json"

# %%
df_data = pd.read_csv(CSV_PATHNAME)
df_data.head()
# Out:
#    순번                                            대학명  \
# 0   1     GE3(Global Engineering Education Exchange)
# 1   2  ISEP(International Student Exchange Programs)
# 2   3                           University of Twente
# 3   4       Amsterdam University of Applied Sciences
# 4   5       Amsterdam University of Applied Sciences
#
#                                                 웹사이트 언어권    국가        학제  \
# 0                  http://globale3.studioabroad.com/  기타     -  프로그램별 상이
# 1  Find a program that's right for you on our pro...  기타     -  프로그램별 상이
# 2                                 www.utwente.nl/en/  유럽  네덜란드  Semester
# 3  https://www.amsterdamuas.com/education/exchang...  유럽  네덜란드  Semester
# 4  https://www.amsterdamuas.com/education/exchang...  유럽  네덜란드  Semester
#
#    파견인원-TO                                            파견인원-비고        파견기간  \
# 0        7                                                NaN  1년 or 한 학기
# ...

# %%
df_data.columns = ['idx', 'univ-name', 'pgm-link', 'lang', 'country'
                  'semester', '']
# Out:
# Index(['순번', '대학명', '웹사이트', '언어권', '국가', '학제', '파견인원-TO', '파견인원-비고', '파견기간',
#        '국적 제한', '파견 직전학기 본교 휴학가능 여부', 'GPA', '만점 기준', 'TOEFL IBT',
#        'IELTS Academic', 'TOEFL ITP', '지원자격-기타', '지원자격-비고', '수강제한학과',
#        '타학과 수강가능여부', '영어수업\n제공여부', '수업-참고링크', '수업-비고', 'On-campus 기숙사',
#        'Off-campus 기숙사', 'accomodation-Others', '월 예상경비(USD)', 'Nomination',
#        'Application'],
#       dtype='object')
