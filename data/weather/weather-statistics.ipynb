# %% [markdown]
# # Collect Weather Statistics
#
# From [the World Weather Information Service](https://worldweather.wmo.int/en/dataguide.html), it provides API
# about forecast and climatological information of each city. It is the API path that `https://worldweather.wmo.int/en/json/[City ID]_en.json` and `[City ID]` is available at [this list](./full_city_list.txt). JSON's Schema information is [here](./WWIS_json_schema_v2.json).

# %% [markdown]
# ## Update Cities of Universities

# %%
import numpy as np
import pandas as pd
pd.options.display.max_columns = None

UNIV_PATHNAME = '../univ-with-qs.csv'
df_univ = pd.read_csv(UNIV_PATHNAME)
df_univ.head()
# Out:
#    sequence                                           name  region  \
# 0         1     GE3(Global Engineering Education Exchange)  Others
# 1         2  ISEP(International Student Exchange Programs)  Others
# 2         3                           University of Twente  Europe
# 3         4       Amsterdam University of Applied Sciences  Europe
# 4         5       Amsterdam University of Applied Sciences  Europe
#
#        country      city                      official-link  established  \
# 0          NaN       NaN  https://globale3.studioabroad.com          NaN
# 1          NaN       NaN                                NaN          NaN
# 2  Netherlands  Enschede             http://www.utwente.nl/       1961.0
# 3  Netherlands       NaN                                NaN          NaN
# 4  Netherlands       NaN                                NaN          NaN
#
#    student-number  faculty-number  campus-size  \
# 0             NaN             NaN          NaN
# 1             NaN             NaN          NaN
# 2         12544.0          3150.0        146.0
# 3             NaN             NaN          NaN
# 4             NaN             NaN          NaN
#
#                                           map-iframe                   loc  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2  https://www.google.com/maps/embed?pb=!1m18!1m1...  Enschede,Netherlands
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
#
#   tot-rank tot-score  tot-international-students-ratio  \
# 0      NaN       NaN                               NaN
# 1      NaN       NaN                               NaN
# 2     =189      45.5                              89.1
# 3      NaN       NaN                               NaN
# 4      NaN       NaN                               NaN
#
#    tot-international-faculty-ratio  tot-faculty-student ratio  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                             98.8                       37.1
# 3                              NaN                        NaN
# 4                              NaN                        NaN
#
#    tot-citations-per-faculty  tot-academic-reputation  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                       79.3                     21.0
# 3                        NaN                      NaN
# 4                        NaN                      NaN
#
#    tot-employer-reputation cse-rank  cse-overall-score  cse-h-index-citations  \
# 0                      NaN      NaN                NaN                    NaN
# 1                      NaN      NaN                NaN                    NaN
# 2                     42.3  151-200                NaN                    NaN
# 3                      NaN      NaN                NaN                    NaN
# 4                      NaN      NaN                NaN                    NaN
#
#    cse-citations-per paper  cse-academic-reputation  cse-employer-reputation  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#   hum-rank  hum-overall-score  hum-h-index-citations  hum-citations-per-paper  \
# 0      NaN                NaN                    NaN                      NaN
# 1      NaN                NaN                    NaN                      NaN
# 2  151-200                NaN                    NaN                      NaN
# 3      NaN                NaN                    NaN                      NaN
# 4      NaN                NaN                    NaN                      NaN
#
#    hum-academic-reputation  hum-employer-reputation
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                      NaN                      NaN

# %%
# Count missing cities
print('missing', len(df_univ[pd.isna(df_univ['city'])]))

# Count available cities
print('available', len(df_univ[pd.isna(df_univ['city']) & ~pd.isna(df_univ['loc'])]))
# Out:
# missing 84
# available 36

# %%
# Row Index
rowIdx = pd.isna(df_univ['city']) & ~pd.isna(df_univ['loc'])

# Regex replace
df_univ.loc[rowIdx, 'loc'].str.replace(',(.+)$', '', regex=True)[:3]
# Out:
# 23    Luxembourg
# 24        Kaunas
# 25      Vilnius
# Name: loc, dtype: object

# %%
# Assign cities
df_univ.loc[rowIdx, 'city'] = df_univ.loc[rowIdx, 'loc'].str.replace(',(.+)$', '', regex=True)

# Trim
df_univ['city'] = df_univ['city'].str.strip()

df_univ[rowIdx].head()
# Out:
#     sequence                                    name  region     country  \
# 23        24                University of Luxembourg  Europe  Luxembourg
# 24        25         Kaunas University of Technology  Europe   Lithuania
# 25        26  Vilnius Gediminas Technical University  Europe   Lithuania
# 27        47                    Linkoping University  Europe      Sweden
# 28        48                  University of Lausanne  Europe       Swiss
#
#           city official-link  established  student-number  faculty-number  \
# 23  Luxembourg           NaN          NaN             NaN             NaN
# 24      Kaunas           NaN          NaN             NaN             NaN
# 25     Vilnius           NaN          NaN             NaN             NaN
# 27   Linköping           NaN          NaN             NaN             NaN
# 28    Lausanne           NaN          NaN             NaN             NaN
#
#     campus-size map-iframe                    loc  tot-rank tot-score  \
# 23          NaN        NaN  Luxembourg,Luxembourg       NaN       NaN
# 24          NaN        NaN       Kaunas,Lithuania  801-1000         -
# 25          NaN        NaN     Vilnius ,Lithuania       NaN       NaN
# 27          NaN        NaN       Linköping,Sweden       329      32.5
# 28          NaN        NaN   Lausanne,Switzerland       176      46.6
#
#     tot-international-students-ratio  tot-international-faculty-ratio  \
# 23                               NaN                              NaN
# 24                              11.2                              1.4
# 25                               NaN                              NaN
# 27                              26.5                             53.6
# 28                              61.7                             99.8
#
#     tot-faculty-student ratio  tot-citations-per-faculty  \
# 23                        NaN                        NaN
# 24                       32.8                        5.4
# 25                        NaN                        NaN
# 27                       29.8                       57.8
# 28                       52.4                       63.9
#
#     tot-academic-reputation  tot-employer-reputation cse-rank  \
# 23                      NaN                      NaN  251-300
# 24                     11.3                     16.3      NaN
# 25                      NaN                      NaN  501-550
# 27                     20.1                     27.9  201-250
# 28                     32.8                     19.0      NaN
#
#     cse-overall-score  cse-h-index-citations  cse-citations-per paper  \
# 23                NaN                   82.7                     88.0
# 24                NaN                    NaN                      NaN
# 25                NaN                    NaN                      NaN
# 27                NaN                   82.2                     91.1
# 28                NaN                    NaN                      NaN
#
#     cse-academic-reputation  cse-employer-reputation hum-rank  \
# 23                      NaN                      NaN  251-300
# 24                      NaN                      NaN      NaN
# 25                      NaN                      NaN  501-550
# 27                      NaN                      NaN  201-250
# 28                      NaN                      NaN      NaN
#
#     hum-overall-score  hum-h-index-citations  hum-citations-per-paper  \
# 23                NaN                   82.7                     88.0
# 24                NaN                    NaN                      NaN
# 25                NaN                    NaN                      NaN
# 27                NaN                   82.2                     91.1
# 28                NaN                    NaN                      NaN
#
#     hum-academic-reputation  hum-employer-reputation
# 23                      NaN                      NaN
# 24                      NaN                      NaN
# 25                      NaN                      NaN
# 27                      NaN                      NaN
# 28                      NaN                      NaN

# %%
# Get city list
df_ucity = df_univ[['country', 'city']].dropna().drop_duplicates(ignore_index=True)
df_ucity.rename(columns={'country': 'univ-country', 'city': 'univ-city'}, inplace=True)
df_ucity.head()
# Out:
#   univ-country   univ-city
# 0  Netherlands    Enschede
# 1      Germany    Konstanz
# 2   Luxembourg  Luxembourg
# 3    Lithuania      Kaunas
# 4    Lithuania     Vilnius

# %% [markdown]
# ## Load City List of Weather

# %%
CITY_PATHNAME = './full_city_list.txt'

df_list = pd.read_csv(CITY_PATHNAME, delimiter=';')
df_list.drop(index=len(df_list)-1, inplace=True) # Last Row is updated time
df_list.tail()
# Out:
#        Country            City  CityId
# 2965  Zimbabwe    Mount Darwin   956.0
# 2966  Zimbabwe          Mutare   954.0
# 2967  Zimbabwe        Plumtree   960.0
# 2968  Zimbabwe          Rusape   959.0
# 2969  Zimbabwe  Victoria Falls   962.0

# %%
df_city = pd.merge(left=df_ucity, right=df_list, how='left',
                    left_on='univ-city', right_on='City')
df_city[~pd.isna(df_city['CityId'])].head()
# Out:
#   univ-country   univ-city     Country        City  CityId
# 2   Luxembourg  Luxembourg  Luxembourg  Luxembourg   192.0
# 3    Lithuania      Kaunas   Lithuania      Kaunas   607.0
# 4    Lithuania     Vilnius   Lithuania     Vilnius   204.0
# 8        Spain      Madrid       Spain      Madrid   195.0
# 9           UK   Sheffield   Australia   Sheffield  1821.0

# %% [markdown]
# ### Mismatched data

# %%
df_city[(df_city['univ-country'] != df_city['Country']) & (~pd.isna(df_city['CityId']))]
# Out:
#                 univ-country            univ-city  \
# 9                         UK            Sheffield
# 10                        UK                Leeds
# 16                    Brunei  Bandar Seri Begawan
# 19                 Hong Kong            Hong Kong
# 23  United States of America             Portland
# 27                    Canada              Toronto
#
#                                               Country                 City  \
# 9                                           Australia            Sheffield
# 10  United Kingdom of Great Britain and Northern I...                Leeds
# 16                                  Brunei Darussalam  Bandar Seri Begawan
# 19                                   Hong Kong, China            Hong Kong
# 23                                          Australia             Portland
# 27                                          Australia              Toronto
#
#     CityId
# 9   1821.0
# 10    39.0
# 16    95.0
# 19     1.0
# 23  1720.0
# 27  1739.0

# %%
# UK Sheffield -> UK Manchester (nearby)
df_city.loc[9, ['Country', 'City', 'CityId']] = df_list[df_list['City'] == 'Manchester'].values[0]

# US Portland -> US Portland, Origon
df_city.loc[23, ['Country', 'City', 'CityId']] = df_list[df_list['City'] == 'Portland, Oregon'].values[0]

# Canada Toronto -> Canada Toronto, Ontario
df_city.loc[27, ['Country', 'City', 'CityId']] = df_list[df_list['City'] == 'Toronto, Ontario'].values[0]

# %% [markdown]
# ### Missing data

# %%
def set_city(city_idx, list_idx):
    df_city.loc[city_idx, ['Country', 'City', 'CityId']] = df_list.loc[list_idx].values

# %%
df_city[pd.isna(df_city['CityId'])]
# Out:
#                 univ-country   univ-city Country City  CityId
# 0                Netherlands    Enschede     NaN  NaN     NaN
# 1                    Germany    Konstanz     NaN  NaN     NaN
# 5                     Sweden   Linköping     NaN  NaN     NaN
# 6                      Swiss    Lausanne     NaN  NaN     NaN
# 7                      Swiss  St. Gallen     NaN  NaN     NaN
# 11                     Italy       Genoa     NaN  NaN     NaN
# 12                     Italy       Milan     NaN  NaN     NaN
# 20  United States of America     Raleigh     NaN  NaN     NaN
# 21  United States of America       Tempe     NaN  NaN     NaN
# 22  United States of America  Blacksburg     NaN  NaN     NaN
# 24  United States of America     Atlanta     NaN  NaN     NaN
# 25  United States of America   Flagstaff     NaN  NaN     NaN
# 26  United States of America      Eugene     NaN  NaN     NaN
# 28                    Canada    Montreal     NaN  NaN     NaN
# 30      United Arab Emirates      Al Ain     NaN  NaN     NaN
# 33                 Australia      Magill     NaN  NaN     NaN

# %%
# Mapping city with CityId
mapper = [
    [0, 1963], [1, 2531], [5, 2524], [6, 2529], [7, 2531],
    [11, 1691], [12, 1694], [20, 2832], [21, 2895], [22, 2838],
    [24, 2659], [25, 2722], [26, 2717], [28, 1082], [30, 2044], [33, 140]
]

for c, l in mapper:
    set_city(c, l)

# %% [markdown]
# ## Load Data

# %%
# Get ID list
id_list = df_city['CityId'].unique().astype(int).tolist()
print(id_list)
# Out:
# [145, 312, 192, 607, 204, 1043, 193, 195, 31, 39, 1948, 603, 48, 47, 82, 95, 234, 2237, 1, 813, 848, 817, 810, 268, 757, 753, 264, 634, 1062, 1395, 1498, 320, 1676, 300, 402]

# %%
import requests
import time

output_arr = list()

for id in id_list:
    # Request
    r = requests.get(f"https://worldweather.wmo.int/en/json/{id}_en.json")
    output_arr.append(r.json()['city'])
    
    # Suspend 1 sec
    print(id, r.json()['city']['cityName'], end=' ')
    time.sleep(1)
# Out:
# 145 Twenthe 312 Zurich 192 Luxembourg 607 Kaunas 204 Vilnius 1043 Norrkoping 193 Geneva 195 Madrid 31 Manchester 39 Leeds 1948 Genova 603 Milan (MILANO) 48 Ankara 47 Istanbul 82 Kuala Lumpur 95 Bandar Seri Begawan 234 Singapore 2237 Bandung 1 Hong Kong 813 Raleigh & Durham, North Carolina 848 Yuma, Arizona 817 Roanoke, Virginia 810 Portland, Oregon 268 Atlanta, Georgia 757 Flagstaff, Arizona 753 Eugene, Oregon 264 Toronto, Ontario 634 Montreal, Quebec 1062 Belo Horizonte 1395 Buraimi 1498 Kuwait City 320 Brisbane 1676 Glenelg 300 Sydney 402 Geelong

# %%
# Save JSON

import json

WEATHER_PATHNAME = './city-weather.json'

with open(WEATHER_PATHNAME, 'w') as f:
    json.dump(output_arr, f)

# %%
with open(WEATHER_PATHNAME, 'r') as f:
    json_data = json.load(f)

assert len(json_data) == len(id_list)

# %% [markdown]
# ## Save Mapper Info

# %%
df_map = df_univ[['sequence', 'name', 'region', 'country', 'city']]
df_map.head()
# Out:
#    sequence                                           name  region  \
# 0         1     GE3(Global Engineering Education Exchange)  Others
# 1         2  ISEP(International Student Exchange Programs)  Others
# 2         3                           University of Twente  Europe
# 3         4       Amsterdam University of Applied Sciences  Europe
# 4         5       Amsterdam University of Applied Sciences  Europe
#
#        country      city
# 0          NaN       NaN
# 1          NaN       NaN
# 2  Netherlands  Enschede
# 3  Netherlands       NaN
# 4  Netherlands       NaN

# %%
df_map = pd.merge(left=df_map, right=df_city, how='left',
                  left_on=['country', 'city'], right_on=['univ-country', 'univ-city'])
df_map.head()
# Out:
#    sequence                                           name  region  \
# 0         1     GE3(Global Engineering Education Exchange)  Others
# 1         2  ISEP(International Student Exchange Programs)  Others
# 2         3                           University of Twente  Europe
# 3         4       Amsterdam University of Applied Sciences  Europe
# 4         5       Amsterdam University of Applied Sciences  Europe
#
#        country      city univ-country univ-city      Country     City  CityId
# 0          NaN       NaN          NaN       NaN          NaN      NaN     NaN
# 1          NaN       NaN          NaN       NaN          NaN      NaN     NaN
# 2  Netherlands  Enschede  Netherlands  Enschede  Netherlands  Twenthe   145.0
# 3  Netherlands       NaN          NaN       NaN          NaN      NaN     NaN
# 4  Netherlands       NaN          NaN       NaN          NaN      NaN     NaN

# %%
MAPPER_PATHNAME = 'univ-city.csv'

df_map.to_csv(MAPPER_PATHNAME, index=False,
              columns=['sequence', 'name', 'region', 'country', 'city', 'CityId'],
             float_format='%.0f')
